# %%
import os
os.chdir("C:\\Users\\Intern\\CSV Conversion & Validation\\Projects")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Laptop/laptop_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
data = data.drop(columns=['Unnamed: 0'])

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
data.shape
# Out:
# (1303, 11)

# %% [markdown]
# Data Cleaning

# %%
data['Ram'] = data['Ram'].str.replace('GB', '')
data['Weight'] = data['Weight'].str.replace('kg', '')

# %%
data.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
data['Ram'] = data['Ram'].astype('int32')
data['Weight'] = data['Weight'].astype('float32')

# %%
sns.distplot(data['Price'])
# Out:
# C:\Users\Intern\AppData\Local\Temp\ipykernel_14992\4196895882.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
data['Company'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Company'>

# %%
data['TypeName'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='TypeName'>

# %%
# We will also try to derive the relation between price and company
plt.figure(figsize=(18,10))
sns.barplot(x=data['Company'], y=data['Price'])
plt.show()

# %%
data['Inches'].value_counts()
# Out:
# Inches
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 13.5      6
# 12.0      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: count, dtype: int64

# %%
sns.scatterplot(x=data['Inches'], y=data['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
data['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# ...

# %%
data['Touchscreen'] = data['ScreenResolution'].apply(lambda x: 0 if 'Touchscreen' not in x else 1)

# %%
data['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
sns.barplot(x = data['Touchscreen'], y=data['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
data['IPS'] = data['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
data['IPS'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='IPS'>

# %%
# Getting the dimensions as integers
data[['XRes', 'Yres']] = data['ScreenResolution'].str.extract(r'(\d{3,4})x(\d{3,4})').astype(int)

# %%
# Creating a new columns named ppi

data['ppi'] = (((data['XRes']**2) + (data['Yres']**2))**0.5/data['Inches']).astype('float')

# %%
data.drop(columns=['ScreenResolution'], inplace=True)

# %%
data['Cpu Name'] = data['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
data['Cpu Name'].value_counts()
# Out:
# Cpu Name
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# Intel Celeron Quad            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# AMD A9-Series 9410            3
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD E-Series E2-9000e         2
# AMD A10-Series A10-9620P      2
# AMD A6-Series A6-9220         2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1505M           2
# Intel Xeon E3-1535M           2
# Intel Atom X5-Z8350           2
# Intel Atom x5-Z8300           1
# AMD E-Series 6110             1
# AMD E-Series 9000e            1
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
data['Cpu brand'] = data['Cpu Name'].apply(fetch_processor)

# %%
data['Cpu brand'].value_counts()
# Out:
# Cpu brand
# Intel Core i7            527
# Intel Core i5            423
# Other Intel Processor    154
# Intel Core i3            136
# AMD Processor             63
# Name: count, dtype: int64

# %%
sns.barplot(x = data['Cpu brand'], y = data['Price'])
# Out:
# <Axes: xlabel='Cpu brand', ylabel='Price'>

# %%
data.drop(columns=['Cpu', 'Cpu Name'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches  Ram               Memory  \
# 0   Apple  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Ultrabook    13.3    8  128GB Flash Storage
# 2      HP   Notebook    15.6    8            256GB SSD
# 3   Apple  Ultrabook    15.4   16            512GB SSD
# 4   Apple  Ultrabook    13.3    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    XRes  Yres         ppi      Cpu brand
# 0  2560  1600  226.983005  Intel Core i5
# 1  1440   900  127.677940  Intel Core i5
# ...

# %%
data['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
data['Memory'] = data['Memory'].astype(str).replace('\.0', '', regex=True)
data["Memory"] = data["Memory"].str.replace('GB', '')
data["Memory"] = data["Memory"].str.replace('TB', '000')
new = data["Memory"].str.split("+", n=1, expand=True)

data["first"] = new[0].str.strip()
data["second"] = new[1] if 1 in new.columns else "0"

data["second"] = data["second"].fillna("0")

data["Layer1HDD"] = data["first"].apply(lambda x: 1 if "HDD" in x else 0)
data["Layer1SSD"] = data["first"].apply(lambda x: 1 if "SSD" in x else 0)
data["Layer1Hybrid"] = data["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
data["Layer1Flash_Storage"] = data["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

data['first'] = data['first'].str.extract(r'(\d+)')[0].fillna('0')

data["Layer2HDD"] = data["second"].apply(lambda x: 1 if "HDD" in x else 0)
data["Layer2SSD"] = data["second"].apply(lambda x: 1 if "SSD" in x else 0)
data["Layer2Hybrid"] = data["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
data["Layer2Flash_Storage"] = data["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

data['second'] = data['second'].str.extract(r'(\d+)')[0].fillna('0')

data["first"] = data["first"].astype(int)
data["second"] = data["second"].astype(int)

data["HDD"] = (data["first"] * data["Layer1HDD"] + data["second"] * data["Layer2HDD"])
data["SSD"] = (data["first"] * data["Layer1SSD"] + data["second"] * data["Layer2SSD"])
data["Hybrid"] = (data["first"] * data["Layer1Hybrid"] + data["second"] * data["Layer2Hybrid"])
data["Flash_Storage"] = (data["first"] * data["Layer1Flash_Storage"] + data["second"] * data["Layer2Flash_Storage"])

data.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'], inplace=True)

# %%
data.head()
# Out:
#   Company   TypeName  Inches  Ram             Memory  \
# 0   Apple  Ultrabook    13.3    8            128 SSD
# 1   Apple  Ultrabook    13.3    8  128 Flash Storage
# 2      HP   Notebook    15.6    8            256 SSD
# 3   Apple  Ultrabook    15.4   16            512 SSD
# 4   Apple  Ultrabook    13.3    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    XRes  Yres         ppi      Cpu brand  HDD  SSD  Hybrid  Flash_Storage
# 0  2560  1600  226.983005  Intel Core i5    0  128       0              0
# ...

# %%
data = data.drop(columns=['Memory'])

# %%
data.drop(columns=['Hybrid','Flash_Storage'],inplace=True) #No correlation between these and price

# %%
data.head()
# Out:
#   Company   TypeName  Inches  Ram                           Gpu  OpSys  \
# 0   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook    13.3    8        Intel HD Graphics 6000  macOS
# 2      HP   Notebook    15.6    8         Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook    15.4   16            AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  IPS  XRes  Yres         ppi  \
# 0    1.37   71378.6832            0    1  2560  1600  226.983005
# 1    1.34   47895.5232            0    0  1440   900  127.677940
# 2    1.86   30636.0000            0    0  1920  1080  141.211998
# 3    1.83  135195.3360            0    1  2880  1800  220.534624
# 4    1.37   96095.8080            0    1  2560  1600  226.983005
#
#        Cpu brand  HDD  SSD
# 0  Intel Core i5    0  128
# 1  Intel Core i5    0    0
# 2  Intel Core i5    0  256
# 3  Intel Core i7    0  512
# ...

# %%
data['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
data['GPU Brand'] = data['Gpu'].apply(lambda x: x.split()[0])

# %%
data['GPU Brand'].value_counts()
# Out:
# GPU Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
data = data[data['GPU Brand'] != 'ARM']

# %%
data = data.drop(columns=['Gpu'])

# %%
data.shape
# Out:
# (1302, 16)

# %%
data['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
data['OS'] = data['OpSys'].apply(cat_os)

# %%
data.drop(columns=['OpSys'])
# Out:
#      Company            TypeName  Inches  Ram  Weight        Price  \
# 0      Apple           Ultrabook    13.3    8    1.37   71378.6832
# 1      Apple           Ultrabook    13.3    8    1.34   47895.5232
# 2         HP            Notebook    15.6    8    1.86   30636.0000
# 3      Apple           Ultrabook    15.4   16    1.83  135195.3360
# 4      Apple           Ultrabook    13.3    8    1.37   96095.8080
# ...      ...                 ...     ...  ...     ...          ...
# 1298  Lenovo  2 in 1 Convertible    14.0    4    1.80   33992.6400
# 1299  Lenovo  2 in 1 Convertible    13.3   16    1.30   79866.7200
# 1300  Lenovo            Notebook    14.0    2    1.50   12201.1200
# 1301      HP            Notebook    15.6    6    2.19   40705.9200
# 1302    Asus            Notebook    15.6    4    2.20   19660.3200
#
#       Touchscreen  IPS  XRes  Yres         ppi              Cpu brand   HDD  \
# 0               0    1  2560  1600  226.983005          Intel Core i5     0
# ...

# %%
sns.distplot(data['Weight'])
# Out:
# C:\Users\Intern\AppData\Local\Temp\ipykernel_14992\2799343561.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %% [markdown]
# Machine Learning

# %%
X = data.drop(columns=['Price'])
y = data['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_train.shape, X_test.shape
# Out:
# ((1041, 16), (261, 16))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.linear_model import LinearRegression,Ridge,Lasso #Regularization to prevent overfitting
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
X.head()
# Out:
#   Company   TypeName  Inches  Ram  OpSys  Weight  Touchscreen  IPS  XRes  \
# 0   Apple  Ultrabook    13.3    8  macOS    1.37            0    1  2560
# 1   Apple  Ultrabook    13.3    8  macOS    1.34            0    0  1440
# 2      HP   Notebook    15.6    8  No OS    1.86            0    0  1920
# 3   Apple  Ultrabook    15.4   16  macOS    1.83            0    1  2880
# 4   Apple  Ultrabook    13.3    8  macOS    1.37            0    1  2560
#
#    Yres         ppi      Cpu brand  HDD  SSD GPU Brand                  OS
# 0  1600  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1   900  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  1080  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  1800  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  1600  226.983005  Intel Core i5    0  256     Intel                 Mac

# %% [markdown]
# LINEAR REGRESSION

# %%
transform =  ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,4,11,14,15])],remainder='passthrough')

# %%
linear = LinearRegression()

# %%
pipe = Pipeline([('Transformation', transform), ('Model', linear)])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('Transformation',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   [0, 1, 4, 11, 14, 15])])),
#                 ('Model', LinearRegression())])

# %%
test_predict = pipe.predict(X_test)

# %%
test_accuracy = r2_score(y_test, test_predict)
mae_test = mean_absolute_error(y_test, test_predict)
print("R2 Score for Test Data: ", test_accuracy)
print("Mean Absolute Error for Test Data: ", mae_test)
# Out:
# R2 Score for Test Data:  0.7040799866484769
# Mean Absolute Error for Test Data:  12719.503398211966

# %% [markdown]
# RIDGE REGRESSION

# %%
transform =  ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,4,11,14,15])],remainder='passthrough')

ridge = Ridge(alpha=10)

ridge_pipe = Pipeline([('Transformation', transform), ('Model', ridge)])

ridge_pipe.fit(X_train, y_train)
ridge_pred = ridge_pipe.predict(X_test)

ridge_accuracy = r2_score(y_test, ridge_pred)
mae_ridge = mean_absolute_error(y_test, ridge_pred)

print("R2 Score for Test Data: ", ridge_accuracy)
print("Mean Absolute Error for Test Data: ", mae_ridge)
# Out:
# R2 Score for Test Data:  0.720799455529844
# Mean Absolute Error for Test Data:  12437.870433144815

# %% [markdown]
# LASSO REGRESSION

# %%
transform =  ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,4,11,14,15])],remainder='passthrough')

lasso = Lasso(alpha=0.001)

lasso_pipe = Pipeline([('Transformation', transform), ('Model', lasso)])

lasso_pipe.fit(X_train, y_train)
lasso_pred = lasso_pipe.predict(X_test)

lasso_accuracy = r2_score(y_test, lasso_pred)
mae_lasso = mean_absolute_error(y_test, lasso_pred)

print("R2 Score for Test Data: ", lasso_accuracy)
print("Mean Absolute Error for Test Data: ", mae_lasso)
# Out:
# R2 Score for Test Data:  0.7036983033041828
# Mean Absolute Error for Test Data:  12745.853744166647
# c:\Users\Intern\CSV Conversion & Validation\t_flow\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.521e+11, tolerance: 1.525e+08
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# KNN

# %%
transform =  ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,4,11,14,15])],remainder='passthrough')

knn = KNeighborsRegressor(n_neighbors=3)

knn_pipe = Pipeline([('Transformation', transform), ('Model', knn)])

knn_pipe.fit(X_train, y_train)
knn_pred = knn_pipe.predict(X_test)

knn_accuracy = r2_score(y_test, knn_pred)
mae_knn = mean_absolute_error(y_test, knn_pred)

print("R2 Score for Test Data: ", knn_accuracy)
print("Mean Absolute Error for Test Data: ", mae_knn)
# Out:
# R2 Score for Test Data:  0.704838483650341
# Mean Absolute Error for Test Data:  11716.889177011493

# %% [markdown]
# SVM

# %%
transform =  ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,4,11,14,15])],remainder='passthrough')

svr = SVR(kernel='rbf',C=10000,epsilon=0.1)

svr_pipe = Pipeline([('Transformation', transform), ('Model', svr)])

svr_pipe.fit(X_train, y_train)
svr_pred = svr_pipe.predict(X_test)

svr_accuracy = r2_score(y_test, svr_pred)
mae_svr = mean_absolute_error(y_test, svr_pred)

print("R2 Score for Test Data: ", svr_accuracy)
print("Mean Absolute Error for Test Data: ", mae_svr)
# Out:
# R2 Score for Test Data:  0.5137328377206773
# Mean Absolute Error for Test Data:  16017.495790244991

# %% [markdown]
# DECISION TREE

# %%
transform =  ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,4,11,14,15])],remainder='passthrough')

tree = DecisionTreeRegressor(max_depth=8)

tree_pipe = Pipeline([('Transformation', transform), ('Model', tree)])

tree_pipe.fit(X_train, y_train)
tree_pred = tree_pipe.predict(X_test)

tree_accuracy = r2_score(y_test, tree_pred)
mae_tree = mean_absolute_error(y_test, tree_pred)

print("R2 Score for Test Data: ", tree_accuracy)
print("Mean Absolute Error for Test Data: ", mae_tree)
# Out:
# R2 Score for Test Data:  0.6103711949916124
# Mean Absolute Error for Test Data:  12129.338790864256

# %% [markdown]
# RANDOM FOREST

# %%
transform =  ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,4,11,14,15])],remainder='passthrough')

rf = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

rf_pipe = Pipeline([('Transformation', transform), ('Model', rf)])

rf_pipe.fit(X_train, y_train)
rf_pred = rf_pipe.predict(X_test)

rf_accuracy = r2_score(y_test, rf_pred)
mae_rf = mean_absolute_error(y_test, rf_pred)

print("R2 Score for Test Data: ", rf_accuracy)
print("Mean Absolute Error for Test Data: ", mae_rf)
# Out:
# R2 Score for Test Data:  0.8015155710765337
# Mean Absolute Error for Test Data:  9659.094665776689

# %% [markdown]
# EXTRA TREES

# %%
transform =  ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,4,11,14,15])],remainder='passthrough')

rf = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=None,
                              max_features=0.75,
                              max_depth=15)

rf_pipe = Pipeline([('Transformation', transform), ('Model', rf)])

rf_pipe.fit(X_train, y_train)
rf_pred = rf_pipe.predict(X_test)

rf_accuracy = r2_score(y_test, rf_pred)
mae_rf = mean_absolute_error(y_test, rf_pred)

print("R2 Score for Test Data: ", rf_accuracy)
print("Mean Absolute Error for Test Data: ", mae_rf)
# Out:
# R2 Score for Test Data:  0.7780441243272338
# Mean Absolute Error for Test Data:  9698.521937994168

# %% [markdown]
# ADABOOST

# %%
transform =  ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,4,11,14,15])],remainder='passthrough')

ada = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

ada_pipe = Pipeline([('Transformation', transform), ('Model', ada)])

ada_pipe.fit(X_train, y_train)
ada_pred = ada_pipe.predict(X_test)

ada_accuracy = r2_score(y_test, ada_pred)
mae_ada = mean_absolute_error(y_test, ada_pred)

print("R2 Score for Test Data: ", ada_accuracy)
print("Mean Absolute Error for Test Data: ", mae_ada)
# Out:
# R2 Score for Test Data:  0.6469243760517778
# Mean Absolute Error for Test Data:  14815.25270490672

# %% [markdown]
# GRADIENTBOOST

# %%
transform =  ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,4,11,14,15])],remainder='passthrough')

ada = GradientBoostingRegressor(n_estimators=500)

ada_pipe = Pipeline([('Transformation', transform), ('Model', ada)])

ada_pipe.fit(X_train, y_train)
ada_pred = ada_pipe.predict(X_test)

ada_accuracy = r2_score(y_test, ada_pred)
mae_ada = mean_absolute_error(y_test, ada_pred)

print("R2 Score for Test Data: ", ada_accuracy)
print("Mean Absolute Error for Test Data: ", mae_ada)
# Out:
# R2 Score for Test Data:  0.7595588554847402
# Mean Absolute Error for Test Data:  9615.066197194517

# %% [markdown]
# XGBOOST

# %%
transform =  ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,4,11,14,15])],remainder='passthrough')

ada = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

ada_pipe = Pipeline([('Transformation', transform), ('Model', ada)])

ada_pipe.fit(X_train, y_train)
ada_pred = ada_pipe.predict(X_test)

ada_accuracy = r2_score(y_test, ada_pred)
mae_ada = mean_absolute_error(y_test, ada_pred)

print("R2 Score for Test Data: ", ada_accuracy)
print("Mean Absolute Error for Test Data: ", mae_ada)
# Out:
# R2 Score for Test Data:  0.7570472630190402
# Mean Absolute Error for Test Data:  9783.283050610633

# %% [markdown]
# VOTING REGRESSOR

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,4,11,14,15])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=None,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=None,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.803096034954696
# MAE 9441.082634612258

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,4,11,14,15])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=None,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8152263402074773
# MAE 9298.02308700669

# %%
import pickle

pickle.dump(data,open('Laptop/laptop_data.pkl','wb'))
pickle.dump(pipe,open('Models/laptop.pkl','wb'))
